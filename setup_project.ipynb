# %%
import os

base = "E:/HealthGuard_AI"

folders = [
    "data/raw",
    "data/processed",
    "notebooks/EDA",
    "notebooks/models",
    "models/saved",
    "app",
    "reports"
]

for folder in folders:
    path = os.path.join(base, folder)
    os.makedirs(path, exist_ok=True)
    print(f"Created: {path}")

print("HealthGuard AI Project Structure Ready!")
# Out:
# Created: E:/HealthGuard_AI\data/raw
# Created: E:/HealthGuard_AI\data/processed
# Created: E:/HealthGuard_AI\notebooks/EDA
# Created: E:/HealthGuard_AI\notebooks/models
# Created: E:/HealthGuard_AI\models/saved
# Created: E:/HealthGuard_AI\app
# Created: E:/HealthGuard_AI\reports
# HealthGuard AI Project Structure Ready!
